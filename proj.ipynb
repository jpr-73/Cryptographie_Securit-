# %%
 

import socket

host = "vlbeintrocrypto.hevs.ch"
port = 6000

s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
print(host, port)




def messageType(msg):
    header = b"ISC"

    if msg == "t" or msg == "T" :
        header += "t"
    elif msg =="s" or msg == "S":
        header += "s"
    elif msg =="i" or msg == "I":
        header += "i"

    return header

def sizeOfMsg(b):
    result = b[4:]
    result = result[:2]
    return result

def addMsgSize(n): 
    size = b""
    size += n.to_bytes(2, byteorder="big")

    return size
# Out:
# vlbeintrocrypto.hevs.ch 6000
